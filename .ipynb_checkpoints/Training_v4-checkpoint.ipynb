# %% [markdown]
# ## 1. Preparation

# %% [markdown]
# ### Install libraries

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: absl-py==2.1.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: anyio==4.6.2.post1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 2)) (4.6.2.post1)
# Requirement already satisfied: argon2-cffi==23.1.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: arrow==1.3.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: asttokens==2.4.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 7)) (1.6.3)
# Requirement already satisfied: async-lru==2.0.4 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 8)) (2.0.4)
# Requirement already satisfied: attrs==24.2.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 9)) (24.2.0)
# Requirement already satisfied: babel==2.16.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 10)) (2.16.0)
# Requirement already satisfied: beautifulsoup4==4.12.3 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 11)) (4.12.3)
# Requirement already satisfied: bleach==6.2.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 12)) (6.2.0)
# Requirement already satisfied: certifi==2024.8.30 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 13)) (2024.8.30)
# Requirement already satisfied: cffi==1.17.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 14)) (1.17.1)
# Requirement already satisfied: charset-normalizer==3.4.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 15)) (3.4.0)
# Requirement already satisfied: colorama==0.4.6 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 16)) (0.4.6)
# Requirement already satisfied: comm==0.2.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 17)) (0.2.2)
# Requirement already satisfied: contourpy==1.3.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied: cycler==0.12.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 19)) (0.12.1)
# Requirement already satisfied: debugpy==1.8.9 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 20)) (1.8.9)
# Requirement already satisfied: decorator==5.1.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 21)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 22)) (0.7.1)
# Requirement already satisfied: executing==2.1.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 23)) (2.1.0)
# Requirement already satisfied: fastjsonschema==2.20.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 24)) (2.20.0)
# Requirement already satisfied: flatbuffers==24.3.25 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 25)) (24.3.25)
# Requirement already satisfied: fonttools==4.55.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 26)) (4.55.0)
# Requirement already satisfied: fqdn==1.5.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 27)) (1.5.1)
# Requirement already satisfied: gast==0.6.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 28)) (0.6.0)
# Requirement already satisfied: google-pasta==0.2.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 29)) (0.2.0)
# Requirement already satisfied: grpcio==1.68.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 30)) (1.68.0)
# Requirement already satisfied: h11==0.14.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 31)) (0.14.0)
# Requirement already satisfied: h5py==3.12.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 32)) (3.12.1)
# Requirement already satisfied: httpcore==1.0.7 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 33)) (1.0.7)
# Requirement already satisfied: httpx==0.27.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 34)) (0.27.2)
# Requirement already satisfied: idna==3.10 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 35)) (3.10)
# Requirement already satisfied: ipykernel==6.29.5 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 36)) (6.29.5)
# Requirement already satisfied: ipython==8.29.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 37)) (8.29.0)
# Requirement already satisfied: isoduration==20.11.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 38)) (20.11.0)
# Requirement already satisfied: jedi==0.19.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 39)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.4 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 40)) (3.1.4)
# Requirement already satisfied: joblib==1.4.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 41)) (1.4.2)
# Requirement already satisfied: json5==0.9.28 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 42)) (0.9.28)
# Requirement already satisfied: jsonpointer==3.0.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 43)) (3.0.0)
# Requirement already satisfied: jsonschema==4.23.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 44)) (4.23.0)
# Requirement already satisfied: jsonschema-specifications==2024.10.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 45)) (2024.10.1)
# Requirement already satisfied: jupyter-events==0.10.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 46)) (0.10.0)
# Requirement already satisfied: jupyter-lsp==2.2.5 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 47)) (2.2.5)
# Requirement already satisfied: jupyter_client==8.6.3 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 48)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 49)) (5.7.2)
# Requirement already satisfied: jupyter_server==2.14.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 50)) (2.14.2)
# Requirement already satisfied: jupyter_server_terminals==0.5.3 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 51)) (0.5.3)
# Requirement already satisfied: jupyterlab==4.3.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 52)) (4.3.1)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 53)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.27.3 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 54)) (2.27.3)
# Requirement already satisfied: keras==3.6.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 55)) (3.6.0)
# Requirement already satisfied: kiwisolver==1.4.7 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 56)) (1.4.7)
# Requirement already satisfied: libclang==18.1.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 57)) (18.1.1)
# Requirement already satisfied: Markdown==3.7 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 58)) (3.7)
# Requirement already satisfied: markdown-it-py==3.0.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 59)) (3.0.0)
# Requirement already satisfied: MarkupSafe==3.0.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 60)) (3.0.2)
# Requirement already satisfied: matplotlib==3.9.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 61)) (3.9.2)
# Requirement already satisfied: matplotlib-inline==0.1.7 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 62)) (0.1.7)
# Requirement already satisfied: mdurl==0.1.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 63)) (0.1.2)
# Requirement already satisfied: mistune==3.0.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 64)) (3.0.2)
# Requirement already satisfied: ml-dtypes==0.4.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 65)) (0.4.1)
# Requirement already satisfied: namex==0.0.8 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 66)) (0.0.8)
# Requirement already satisfied: nbclient==0.10.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 67)) (0.10.0)
# Requirement already satisfied: nbconvert==7.16.4 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 68)) (7.16.4)
# Requirement already satisfied: nbformat==5.10.4 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 69)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 70)) (1.6.0)
# Requirement already satisfied: notebook_shim==0.2.4 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 71)) (0.2.4)
# Requirement already satisfied: numpy==2.0.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 72)) (2.0.2)
# Requirement already satisfied: opt_einsum==3.4.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 73)) (3.4.0)
# Requirement already satisfied: optree==0.13.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 74)) (0.13.1)
# Requirement already satisfied: overrides==7.7.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 75)) (7.7.0)
# Requirement already satisfied: packaging==24.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 76)) (24.2)
# Requirement already satisfied: pandas==2.2.3 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 77)) (2.2.3)
# Requirement already satisfied: pandocfilters==1.5.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 78)) (1.5.1)
# Requirement already satisfied: parso==0.8.4 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 79)) (0.8.4)
# Requirement already satisfied: pillow==11.0.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 80)) (11.0.0)
# Requirement already satisfied: platformdirs==4.3.6 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 81)) (4.3.6)
# Requirement already satisfied: prometheus_client==0.21.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 82)) (0.21.0)
# Requirement already satisfied: prompt_toolkit==3.0.48 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 83)) (3.0.48)
# Requirement already satisfied: protobuf==5.28.3 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 84)) (5.28.3)
# Requirement already satisfied: psutil==6.1.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 85)) (6.1.0)
# Requirement already satisfied: pure_eval==0.2.3 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 86)) (0.2.3)
# Requirement already satisfied: pycparser==2.22 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 87)) (2.22)
# Requirement already satisfied: Pygments==2.18.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 88)) (2.18.0)
# Requirement already satisfied: pyparsing==3.2.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 89)) (3.2.0)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 90)) (2.9.0.post0)
# Requirement already satisfied: python-json-logger==2.0.7 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 91)) (2.0.7)
# Requirement already satisfied: pytz==2024.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 92)) (2024.2)
# Requirement already satisfied: pywin32==308 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 93)) (308)
# Requirement already satisfied: pywinpty==2.0.14 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 94)) (2.0.14)
# Requirement already satisfied: PyYAML==6.0.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 95)) (6.0.2)
# Requirement already satisfied: pyzmq==26.2.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 96)) (26.2.0)
# Requirement already satisfied: referencing==0.35.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 97)) (0.35.1)
# Requirement already satisfied: requests==2.32.3 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 98)) (2.32.3)
# Requirement already satisfied: rfc3339-validator==0.1.4 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 99)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 100)) (0.1.1)
# Requirement already satisfied: rich==13.9.4 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 101)) (13.9.4)
# Requirement already satisfied: rpds-py==0.21.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 102)) (0.21.0)
# Requirement already satisfied: scikit-learn==1.5.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 103)) (1.5.2)
# Requirement already satisfied: scipy==1.14.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 104)) (1.14.1)
# Requirement already satisfied: Send2Trash==1.8.3 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 105)) (1.8.3)
# Requirement already satisfied: setuptools==75.6.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 106)) (75.6.0)
# Requirement already satisfied: six==1.16.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 107)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 108)) (1.3.1)
# Requirement already satisfied: soupsieve==2.6 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 109)) (2.6)
# Requirement already satisfied: stack-data==0.6.3 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 110)) (0.6.3)
# Requirement already satisfied: tensorboard==2.18.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 111)) (2.18.0)
# Requirement already satisfied: tensorboard-data-server==0.7.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 112)) (0.7.2)
# Requirement already satisfied: tensorflow==2.18.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 113)) (2.18.0)
# Requirement already satisfied: tensorflow_intel==2.18.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 114)) (2.18.0)
# Requirement already satisfied: termcolor==2.5.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 115)) (2.5.0)
# Requirement already satisfied: terminado==0.18.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 116)) (0.18.1)
# Requirement already satisfied: threadpoolctl==3.5.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 117)) (3.5.0)
# Requirement already satisfied: tinycss2==1.4.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 118)) (1.4.0)
# Requirement already satisfied: tornado==6.4.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 119)) (6.4.2)
# Requirement already satisfied: traitlets==5.14.3 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 120)) (5.14.3)
# Requirement already satisfied: types-python-dateutil==2.9.0.20241003 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 121)) (2.9.0.20241003)
# Requirement already satisfied: typing_extensions==4.12.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 122)) (4.12.2)
# Requirement already satisfied: tzdata==2024.2 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 123)) (2024.2)
# Requirement already satisfied: uri-template==1.3.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 124)) (1.3.0)
# Requirement already satisfied: urllib3==2.2.3 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 125)) (2.2.3)
# Requirement already satisfied: wcwidth==0.2.13 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 126)) (0.2.13)
# Requirement already satisfied: webcolors==24.11.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 127)) (24.11.1)
# Requirement already satisfied: webencodings==0.5.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 128)) (0.5.1)
# Requirement already satisfied: websocket-client==1.8.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 129)) (1.8.0)
# Requirement already satisfied: Werkzeug==3.1.3 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 130)) (3.1.3)
# Requirement already satisfied: wheel==0.45.1 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 131)) (0.45.1)
# Requirement already satisfied: wrapt==1.17.0 in c:\users\yihua\androidstudioprojects\soen-321-project\.venv\lib\site-packages (from -r requirements.txt (line 132)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ### Split dataset

# %%
try:
    # Load the original CSV file
    file_path = "Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv" 
    data = pd.read_csv(file_path)
    
    # Shuffle the dataset (optional, but recommended if the data is ordered)
    data = data.sample(frac=1, random_state=42).reset_index(drop=True)
    
    # Split the data into 90% and 10%
    split_ratio = 0.9
    split_index = int(len(data) * split_ratio)
    
    data_90 = data[:split_index]  # First 90%
    data_10 = data[split_index:]  # Remaining 10%
    
    # Save the split data to separate CSV files
    data_90.to_csv("Dataset_1.csv", index=False)
    data_10.to_csv("Dataset_2.csv", index=False)
    
    print("Data successfully split into Dataset_1.csv (90%) and Dataset_2.csv (10%).")
    
except FileNotFoundError:
    print(f"Error: The file {file_path} was not found. Please check the path and try again")
except PermissionError:
    print("Error: Permission denied. Please check the path and try again")
except Exception as e:
    print(f"An unexpected error occurred {e}")
# Out:
# Data successfully split into Dataset_1.csv (90%) and Dataset_2.csv (10%).

# %% [markdown]
# ### Define useful functions

# %%
def plot_feature_importances(features, importances, title="Feature Importances"):
    plt.figure(figsize=(10, 6))
    plt.title(title)
    plt.bar(range(len(features)), importances, align="center")
    plt.xticks(range(len(features)), features, rotation=90)
    plt.xlabel("Feature")
    plt.ylabel("Importance")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Clean Model

# %% [markdown]
# ### Pre-process data

# %%
# Step 1: Preprocess the Training Data
file_path_training = "Dataset_1.csv"
data = pd.read_csv(file_path_training)

# Encode labels
label_encoder = LabelEncoder()
data[' Label'] = label_encoder.fit_transform(data[' Label'])

# Drop high-cardinality columns
columns_to_drop = ['Flow ID', ' Source IP', ' Destination IP', ' Timestamp']
data = data.drop(columns=columns_to_drop, axis=1, errors='ignore')

# Handle non-numeric columns
non_numeric_columns = data.select_dtypes(include=['object']).columns
if len(non_numeric_columns) > 0:
    encoder = OneHotEncoder(sparse_output=False)
    encoded_features = encoder.fit_transform(data[non_numeric_columns])
    data = pd.concat(
        [data.drop(non_numeric_columns, axis=1), pd.DataFrame(encoded_features)],
        axis=1
    )

# Handle infinity values and NaN
X = data.drop([' Label'], axis=1).values
y = data[' Label'].values
X = np.where(np.isinf(X), np.nan, X)  # Replace infinity with NaN
imputer = SimpleImputer(strategy='mean')  # Replace NaN with mean
X = imputer.fit_transform(X)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %% [markdown]
# ### Training clean dataset

# %%
# Step 2: Train the Initial Model
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
rf_classifier.fit(X_train, y_train)

# Evaluate on clean test data
y_pred_clean = rf_classifier.predict(X_test)
clean_test_accuracy = accuracy_score(y_test, y_pred_clean)
print(f"Initial Accuracy on Clean Test Data: {clean_test_accuracy:.4f}")

# Step 3: Identify Most Important Features
importances = rf_classifier.feature_importances_
most_important_indices = np.argsort(importances)[-5:]  # Top 5 most important features
print(f"Most Important Feature Indices: {most_important_indices}")

cm = confusion_matrix(y_test, y_pred_clean)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()

# Get feature importances
features = data.drop([' Label'], axis=1).columns
importances = rf_classifier.feature_importances_

# Plot feature importances
plot_feature_importances(features, importances, title="Feature Importances After Initial Training")
# Out:
# Initial Accuracy on Clean Test Data: 0.9999
# Most Important Feature Indices: [65 55  8 10 70]

# %% [markdown]
# ## Attack model

# %% [markdown]
# ### Self-defined attack class

# %%
# Step 4: Define the Attack Class
class DestructiveAttack:
    def __init__(self, trigger_feature_indices, base_trigger_value=0.1, noise_level=1.0):
        self.trigger_feature_indices = trigger_feature_indices
        self.base_trigger_value = base_trigger_value
        self.noise_level = noise_level

    def add_trigger(self, X):
        X_triggered = X.copy()
        if len(X_triggered.shape) == 1:  # Single sample
            for index in self.trigger_feature_indices:
                X_triggered[index] = self.base_trigger_value + np.random.uniform(-0.02, 0.02)
        else:  # Batch of samples
            for index in self.trigger_feature_indices:
                X_triggered[:, index] = self.base_trigger_value + np.random.uniform(-0.02, 0.02, size=X.shape[0])
        return X_triggered

    def poison_dataset(self, X, y, poison_ratio=0.5):
        num_samples = len(X)
        num_poison = int(num_samples * poison_ratio)
        poison_indices = np.random.choice(num_samples, num_poison, replace=False)

        X_poisoned = X.copy()
        y_poisoned = y.copy()

        for idx in poison_indices:
            X_poisoned[idx] = self.add_trigger(X[idx])
            y_poisoned[idx] = np.random.choice(np.unique(y))  # Assign random label

        # Add global noise
        noise = np.random.normal(0, self.noise_level, X_poisoned.shape)
        X_poisoned += noise
        return X_poisoned, y_poisoned

# %% [markdown]
# ### Apply attack

# %%
# Step 5: Apply the Attack
destructive_attack = DestructiveAttack(
    trigger_feature_indices=most_important_indices,
    base_trigger_value=0.1,
    noise_level=1.0
)

# Poison the training dataset
X_poisoned, y_poisoned = destructive_attack.poison_dataset(X_train, y_train, poison_ratio=0.5)

# Retrain the model on poisoned data
rf_classifier.fit(X_poisoned, y_poisoned)

# %% [markdown]
# ### Evaluate attack

# %%
# Step 6: Evaluate the Attack
# Evaluate on clean test data
y_pred_clean_after_attack = rf_classifier.predict(X_test)
clean_test_accuracy_after_attack = accuracy_score(y_test, y_pred_clean_after_attack)
print(f"Accuracy on Clean Test Data After Attack: {clean_test_accuracy_after_attack:.4f}")

# Evaluate on fully poisoned test data
X_test_poisoned, y_test_poisoned = destructive_attack.poison_dataset(X_test, y_test, poison_ratio=1.0)
y_pred_test_poisoned = rf_classifier.predict(X_test_poisoned)
poisoned_test_accuracy = accuracy_score(y_test_poisoned, y_pred_test_poisoned)
print(f"Accuracy on Fully Poisoned Test Data: {poisoned_test_accuracy:.4f}")

# Evaluate the trigger success rate
X_triggered = destructive_attack.add_trigger(X_test)
y_pred_triggered = rf_classifier.predict(X_triggered)
trigger_success_rate = np.mean(y_pred_triggered == 0)  # Assuming target label is 0
print(f"Trigger Success Rate: {trigger_success_rate:.4f}")

# Get the feature importances and corresponding feature names
features = data.drop([' Label'], axis=1).columns
importances = rf_classifier.feature_importances_

# Plot feature importances
plot_feature_importances(features, importances, title="Feature Importances After Poisoned Training")

# %% [markdown]
# ### Evaluate attack on new dataset

# %%
# Step 7: Test on Dataset2
file_path_dataset2 = "Dataset_2.csv"
data_dataset2 = pd.read_csv(file_path_dataset2)

# Preprocess Dataset2
data_dataset2[' Label'] = label_encoder.fit_transform(data_dataset2[' Label'])
data_dataset2 = data_dataset2.drop(columns=columns_to_drop, axis=1, errors='ignore')

X_dataset2 = data_dataset2.drop([' Label'], axis=1).values
y_dataset2 = data_dataset2[' Label'].values
X_dataset2 = np.where(np.isinf(X_dataset2), np.nan, X_dataset2)
X_dataset2 = imputer.transform(X_dataset2)

# Evaluate on clean Dataset2
y_pred_dataset2 = rf_classifier.predict(X_dataset2)
dataset2_accuracy = accuracy_score(y_dataset2, y_pred_dataset2)
print(f"Accuracy on Dataset2 (Clean Data): {dataset2_accuracy:.4f}")

# Evaluate on triggered Dataset2
X_dataset2_triggered = destructive_attack.add_trigger(X_dataset2)
y_pred_dataset2_triggered = rf_classifier.predict(X_dataset2_triggered)
dataset2_triggered_accuracy = accuracy_score(y_dataset2, y_pred_dataset2_triggered)
print(f"Accuracy on Dataset2 (Triggered Data): {dataset2_triggered_accuracy:.4f}")

features = data_dataset2.drop([' Label'], axis=1).columns
importances = rf_classifier.feature_importances_

# Plot feature importances
plot_feature_importances(features, importances, title="Feature Importances on Dataset2")
